# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay-s216/PP-3-Weekly-Code-Practice/blob/main/Day_3_PP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day_3_PP3- "SET"

# %%
Weather = {"Sunny","Cloudy","Rainy","Air","Windy"}
print(Weather)
print(type(Weather))
# Out:
# {'Windy', 'Air', 'Cloudy', 'Rainy', 'Sunny'}
# <class 'set'>

# %%
Set1 = {1,2,3,4,5}
Set2 = {4,5,6,7,8}
print(type(Set1))
print(type(Set2))
# Out:
# <class 'set'>
# <class 'set'>

# %%
information = {"Read NewsPaper","Practise Code","Develop the game","Repeat"}
print("Today's schedue is :", information)
# Out:
# Today's schedue is : {'Develop the game', 'Practise Code', 'Read NewsPaper', 'Repeat'}

# %%
information = {"Read NewsPaper","Practise Code","Develop the game","Repeat"}
info = {"Read NewsPaper","Repeat"}
print(information|info)
# Out:
# {'Read NewsPaper', 'Practise Code', 'Develop the game', 'Repeat'}

# %%
information = {"Read NewsPaper","Practise Code","Develop the game","Repeat"}
info = {"Read NewsPaper","Repeat"}
print(information.union(info))
# Out:
# {'Read NewsPaper', 'Practise Code', 'Develop the game', 'Repeat'}

# %%
information = {"Read NewsPaper","Practise Code","Develop the game","Repeat"}
info = {"Read NewsPaper","Repeat"}
print(information.intersection(info))
# Out:
# {'Read NewsPaper', 'Repeat'}
